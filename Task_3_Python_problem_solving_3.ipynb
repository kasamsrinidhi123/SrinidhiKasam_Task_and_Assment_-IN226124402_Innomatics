# %% [markdown]
# **Problem Statement 1: Employee Performance Bonus Eligibility**
#
# Requirements:
#
# -Identify the highest performance score.
#
# -Handle ties if multiple employees have the same highest score.
#
# -Display all employees eligible for the top performance bonus.

# %%
employees = {
"Ravi": 92,
"Anita": 88,
"Kiran": 92,
"Suresh": 85
}
#to find highest score
high_score=max(employees.values())
# to find employees with highest score
top_performers=[name for name,score in employees.items() if score==high_score]
print("Top Performers Eligible for Bonus:",",".join(top_performers),f"(Score: {high_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi,Kiran (Score: 92)

# %% [markdown]
# **Problem Statement 2: Search Query Keyword Analysis**
#
# Requirements:
#
# -Convert the input to lowercase.
#
# -Ignore common punctuation.
#
# -Count the frequency of each keyword.
#
# -Display only keywords searched more than once.

# %%
import string
query = "Buy mobile phone buy phone online"
#convert to lowercase
query = query.lower()
#Remove punctuation
for ch in string.punctuation:
    query = query.replace(ch, "")
# Split into words
words = query.split()
#Count frequency
freq = {}
for word in words:
    freq[word] = freq.get(word, 0) + 1
#Keep only words appearing more than once
result = {word: count for word, count in freq.items() if count > 1}
print(result)
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# **Problem Statement 3: Sensor Data Validation**
#
# Requirements:
#
# Identify readings that are even numbers (valid readings).
#
# Store them as (hour_index, reading_value) pairs.
#
# Ignore odd readings (invalid readings).

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]
#to store readings which are vallid
readings=[(index,value) for index ,value in enumerate(sensor_readings) if value%2==0]
print("Valid Sensor Readings (Hour,Value):")
print(readings)
# Out:
# Valid Sensor Readings (Hour,Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# **Problem Statement 4: Email Domain Usage Analysis**
#
# Requirements:
#
# Count how many users belong to each email domain.
#
# Calculate the percentage usage of each domain.

# %%
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]
#to Count domain occurrences
domain_count = {}
for email in emails:
    domain = email.split("@")[1]
    domain_count[domain] = domain_count.get(domain, 0) + 1
# Calculate percentages
total_emails = len(emails)
for domain, count in domain_count.items():
    percentage = (count / total_emails) * 100
    print(f"{domain}: {int(percentage)}%")
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# **Problem Statement 5: Sales Spike Detection**
#
# Requirements:
#
# Calculate the average daily sales.
#
# Detect days where sales are more than 30% above average.
#
# Display the day number and sale value.

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]
# to Calculate average sales
average_sales = sum(sales) / len(sales)
# to Calculate 30% above average threshold
threshold = average_sales * 1.30
# to Detect spike days
for day, value in enumerate(sales, start=1):
    if value > threshold:
        print(f"Day {day}: {value}")
# Out:
# Day 6: 3000

# %% [markdown]
# **Problem Statement 6: Duplicate User ID Detection**
#
# Requirements:
#
# Identify duplicate user IDs.
#
# Display how many times each duplicate appears.

# %%
# user IDs
user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]
# to Count occurrences
count_dict = {}
for uid in user_ids:
    count_dict[uid] = count_dict.get(uid, 0) + 1
# to Display duplicates
for uid, count in count_dict.items():
    if count > 1:
        print(f"{uid} → {count} times")
# Out:
# user1 → 3 times
# user3 → 2 times
